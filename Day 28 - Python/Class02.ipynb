# %% [markdown]
# Python Varaiable Naming Convention

# %%
Name : str = "Muhammad Hashim" # Professional Code
print(Name)
print(id(Name))
print(dir(Name))
display(Name)
# Out:
# Muhammad Hashim
# 1445810396784
# ...
